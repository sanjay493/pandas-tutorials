# %%
import jedi
import pandas as pd
jedi.__version__
# Out:
# '0.19.2'

# %%
df =pd.read_csv('employees.csv')

# %%
df
# Out:
#    EmpID    Name   Department  Age  Salary    JoinDate
# 0    101   Rahul   Production   35   55000  2016-04-12
# 1    102    Amit  Maintenance   42   62000  2014-09-23
# 2    103   Sneha      Quality   29   48000  2019-01-15
# 3    104   Pooja   Production   31   51000  2018-07-30
# 4    105  Vikram    Logistics   45   68000  2012-11-02
# 5    106    Neha      Quality   27   45000  2020-06-18

# %%
df.head()
# Out:
#    EmpID    Name   Department  Age  Salary    JoinDate
# 0    101   Rahul   Production   35   55000  2016-04-12
# 1    102    Amit  Maintenance   42   62000  2014-09-23
# 2    103   Sneha      Quality   29   48000  2019-01-15
# 3    104   Pooja   Production   31   51000  2018-07-30
# 4    105  Vikram    Logistics   45   68000  2012-11-02

# %%
df.tail()
# Out:
#    EmpID    Name   Department  Age  Salary    JoinDate
# 1    102    Amit  Maintenance   42   62000  2014-09-23
# 2    103   Sneha      Quality   29   48000  2019-01-15
# 3    104   Pooja   Production   31   51000  2018-07-30
# 4    105  Vikram    Logistics   45   68000  2012-11-02
# 5    106    Neha      Quality   27   45000  2020-06-18

# %%
df.dtypes
# Out:
# EmpID          int64
# Name          object
# Department    object
# Age            int64
# Salary         int64
# JoinDate      object
# dtype: object

# %%
df1= df[["Name","Salary","Age"]]
df1
# Out:
#      Name  Salary  Age
# 0   Rahul   55000   35
# 1    Amit   62000   42
# 2   Sneha   48000   29
# 3   Pooja   51000   31
# 4  Vikram   68000   45
# 5    Neha   45000   27

# %%
df1.to_csv('New_Eployees.csv')

# %%
import openpyxl
df1.to_excel('New_Employees.xlsx')

# %%
df2 = pd.read_excel('New_Employees.xlsx')
df2
# Out:
#    Unnamed: 0    Name  Salary  Age
# 0           0   Rahul   55000   35
# 1           1    Amit   62000   42
# 2           2   Sneha   48000   29
# 3           3   Pooja   51000   31
# 4           4  Vikram   68000   45
# 5           5    Neha   45000   27

# %%
df
# Out:
#    EmpID    Name   Department  Age  Salary    JoinDate
# 0    101   Rahul   Production   35   55000  2016-04-12
# 1    102    Amit  Maintenance   42   62000  2014-09-23
# 2    103   Sneha      Quality   29   48000  2019-01-15
# 3    104   Pooja   Production   31   51000  2018-07-30
# 4    105  Vikram    Logistics   45   68000  2012-11-02
# 5    106    Neha      Quality   27   45000  2020-06-18

# %%
df['Name'].sort_values()
# Out:
# 1      Amit
# 5      Neha
# 3     Pooja
# 0     Rahul
# 2     Sneha
# 4    Vikram
# Name: Name, dtype: object

# %%
df.sort_values(by="Name", ascending=False)
# Out:
#    EmpID    Name   Department  Age  Salary    JoinDate
# 4    105  Vikram    Logistics   45   68000  2012-11-02
# 2    103   Sneha      Quality   29   48000  2019-01-15
# 0    101   Rahul   Production   35   55000  2016-04-12
# 3    104   Pooja   Production   31   51000  2018-07-30
# 5    106    Neha      Quality   27   45000  2020-06-18
# 1    102    Amit  Maintenance   42   62000  2014-09-23

# %%
df.sort_values(by="Name", ascending=True).reset_index(drop=True)
# Out:
#    EmpID    Name   Department  Age  Salary    JoinDate
# 0    102    Amit  Maintenance   42   62000  2014-09-23
# 1    106    Neha      Quality   27   45000  2020-06-18
# 2    104   Pooja   Production   31   51000  2018-07-30
# 3    101   Rahul   Production   35   55000  2016-04-12
# 4    103   Sneha      Quality   29   48000  2019-01-15
# 5    105  Vikram    Logistics   45   68000  2012-11-02

# %%
df.sort_values(by="Department", ascending=True)
# Out:
#    EmpID    Name   Department  Age  Salary    JoinDate
# 4    105  Vikram    Logistics   45   68000  2012-11-02
# 1    102    Amit  Maintenance   42   62000  2014-09-23
# 0    101   Rahul   Production   35   55000  2016-04-12
# 3    104   Pooja   Production   31   51000  2018-07-30
# 2    103   Sneha      Quality   29   48000  2019-01-15
# 5    106    Neha      Quality   27   45000  2020-06-18

# %%
df.sort_values(by=["Department", "Salary"], ascending=[True, False])
# Out:
#    EmpID    Name   Department  Age  Salary    JoinDate
# 4    105  Vikram    Logistics   45   68000  2012-11-02
# 1    102    Amit  Maintenance   42   62000  2014-09-23
# 0    101   Rahul   Production   35   55000  2016-04-12
# 3    104   Pooja   Production   31   51000  2018-07-30
# 2    103   Sneha      Quality   29   48000  2019-01-15
# 5    106    Neha      Quality   27   45000  2020-06-18

# %%
df.sort_values(by=["Department", "Salary"], ascending=[True, True])
# Out:
#    EmpID    Name   Department  Age  Salary    JoinDate
# 4    105  Vikram    Logistics   45   68000  2012-11-02
# 1    102    Amit  Maintenance   42   62000  2014-09-23
# 3    104   Pooja   Production   31   51000  2018-07-30
# 0    101   Rahul   Production   35   55000  2016-04-12
# 5    106    Neha      Quality   27   45000  2020-06-18
# 2    103   Sneha      Quality   29   48000  2019-01-15

# %%
df[(df["Department"]=="Production") ]
# Out:
#    EmpID   Name  Department  Age  Salary    JoinDate
# 0    101  Rahul  Production   35   55000  2016-04-12
# 3    104  Pooja  Production   31   51000  2018-07-30

# %%
df[(df["Department"]=="Production") & (df["Age"]>31)]
# Out:
#    EmpID   Name  Department  Age  Salary    JoinDate
# 0    101  Rahul  Production   35   55000  2016-04-12

# %%
df[(df["Department"].isin(["Production","Quality"])) | (df["Age"]>31)]
# Out:
#    EmpID    Name   Department  Age  Salary    JoinDate
# 0    101   Rahul   Production   35   55000  2016-04-12
# 1    102    Amit  Maintenance   42   62000  2014-09-23
# 2    103   Sneha      Quality   29   48000  2019-01-15
# 3    104   Pooja   Production   31   51000  2018-07-30
# 4    105  Vikram    Logistics   45   68000  2012-11-02
# 5    106    Neha      Quality   27   45000  2020-06-18

# %%
df[df["Name"].str.startswith("R")]
# Out:
#    EmpID   Name  Department  Age  Salary    JoinDate
# 0    101  Rahul  Production   35   55000  2016-04-12

# %%
df[df["Department"].str.contains("log", case=False, na=False)]
# Out:
#    EmpID    Name Department  Age  Salary    JoinDate
# 4    105  Vikram  Logistics   45   68000  2012-11-02

# %%
df["JoinDate"]
# Out:
# 0   2016-04-12
# 1   2014-09-23
# 2   2019-01-15
# 3   2018-07-30
# 4   2012-11-02
# 5   2020-06-18
# Name: JoinDate, dtype: datetime64[ns]

# %%
pd.to_datetime(df["JoinDate"])
# Out:
# 0   2016-04-12
# 1   2014-09-23
# 2   2019-01-15
# 3   2018-07-30
# 4   2012-11-02
# 5   2020-06-18
# Name: JoinDate, dtype: datetime64[ns]

# %%
df["JoinDate"]=pd.to_datetime(df["JoinDate"])

# %%
df
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate
# 0    101   Rahul   Production   35   55000 2016-04-12
# 1    102    Amit  Maintenance   42   62000 2014-09-23
# 2    103   Sneha      Quality   29   48000 2019-01-15
# 3    104   Pooja   Production   31   51000 2018-07-30
# 4    105  Vikram    Logistics   45   68000 2012-11-02
# 5    106    Neha      Quality   27   45000 2020-06-18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmpID       6 non-null      int64
#  1   Name        6 non-null      object
#  2   Department  6 non-null      object
#  3   Age         6 non-null      int64
#  4   Salary      6 non-null      int64
#  5   JoinDate    6 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 420.0+ bytes

# %%
df
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate
# 0    101   Rahul   Production   35   55000 2016-04-12
# 1    102    Amit  Maintenance   42   62000 2014-09-23
# 2    103   Sneha      Quality   29   48000 2019-01-15
# 3    104   Pooja   Production   31   51000 2018-07-30
# 4    105  Vikram    Logistics   45   68000 2012-11-02
# 5    106    Neha      Quality   27   45000 2020-06-18

# %%
df[(df["Department"].isin(["Production","Quality"]) & (df["Name"].str.endswith("a")))]
# Out:
#    EmpID   Name  Department  Age  Salary   JoinDate
# 2    103  Sneha     Quality   29   48000 2019-01-15
# 3    104  Pooja  Production   31   51000 2018-07-30
# 5    106   Neha     Quality   27   45000 2020-06-18

# %%
df_new = pd.read_csv('employees.csv')

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmpID       6 non-null      int64
#  1   Name        6 non-null      object
#  2   Department  6 non-null      object
#  3   Age         6 non-null      int64
#  4   Salary      6 non-null      int64
#  5   JoinDate    6 non-null      object
# dtypes: int64(3), object(3)
# memory usage: 420.0+ bytes

# %%
df[(df["JoinDate"]>"2018-03-01") & (df["JoinDate"]<"2022-03-31")]
# Out:
#    EmpID   Name  Department  Age  Salary   JoinDate
# 2    103  Sneha     Quality   29   48000 2019-01-15
# 3    104  Pooja  Production   31   51000 2018-07-30
# 5    106   Neha     Quality   27   45000 2020-06-18

# %%
df.sort_values(by="JoinDate",ascending=True)
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate
# 4    105  Vikram    Logistics   45   68000 2012-11-02
# 1    102    Amit  Maintenance   42   62000 2014-09-23
# 0    101   Rahul   Production   35   55000 2016-04-12
# 3    104   Pooja   Production   31   51000 2018-07-30
# 2    103   Sneha      Quality   29   48000 2019-01-15
# 5    106    Neha      Quality   27   45000 2020-06-18

# %%
len(df)
# Out:
# 6

# %%
df.loc[len(df)] = {
    "EmpID": 107,
    "Name": "Manish",
    "Department": "Logistics",
    "Age": 45,
    "Salary": 78000,
    "JoinDate": "2025-10-02 00:00:00"
}

# %%
df
# Out:
#    EmpID    Name   Department  Age  Salary             JoinDate
# 0    101   Rahul   Production   35   55000  2016-04-12 00:00:00
# 1    102    Amit  Maintenance   42   62000  2014-09-23 00:00:00
# 2    103   Sneha      Quality   29   48000  2019-01-15 00:00:00
# 3    104   Pooja   Production   31   51000  2018-07-30 00:00:00
# 4    105  Vikram    Logistics   45   68000  2012-11-02 00:00:00
# 5    106    Neha      Quality   27   45000  2020-06-18 00:00:00
# 6    107  Manish    Logistics   45   78000           2025-10-02
# 7    107  Manish    Logistics   45   78000  2025-10-02 00:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmpID       8 non-null      int64
#  1   Name        8 non-null      object
#  2   Department  8 non-null      object
#  3   Age         8 non-null      int64
#  4   Salary      8 non-null      int64
#  5   JoinDate    8 non-null      object
# dtypes: int64(3), object(3)
# memory usage: 448.0+ bytes

# %%
df.sort_values(by="JoinDate",ascending=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df.sort_values(by="JoinDate",ascending=True)
#
# File ~/pyenv/lib/python3.13/site-packages/pandas/core/frame.py:7222, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7219     if isinstance(ascending, (tuple, list)):
#    7220         ascending = ascending[0]
# -> 7222     indexer = nargsort(
#    7223         k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    7224     )
#    7225 else:
#    7226     if inplace:
#
# File ~/pyenv/lib/python3.13/site-packages/pandas/core/sorting.py:439, in nargsort(items, kind, ascending, na_position, key, mask)
#     437     non_nans = non_nans[::-1]
#     438     non_nan_idx = non_nan_idx[::-1]
# --> 439 indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     440 if not ascending:
# ...

# %%
df.loc[6]
# Out:
# EmpID                107
# Name              Manish
# Department     Logistics
# Age                   45
# Salary             78000
# JoinDate      2025-10-02
# Name: 6, dtype: object

# %%
df.loc[6][2]
# Out:
# /tmp/ipykernel_2207/1648126032.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[6][2]
# 'Logistics'

# %%
df.loc[6][5]="2025-10-02 10:00:00"
# Out:
# /tmp/ipykernel_2207/2963282987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[6][5]="2025-10-02 10:00:00"
# /tmp/ipykernel_2207/2963282987.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df.loc[6][5]="2025-10-02 10:00:00"

# %%
df.loc[6][5]
# Out:
# /tmp/ipykernel_2207/2144239396.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[6][5]
# '2025-10-02'

# %%
df["JoinDate"]
# Out:
# 0    2016-04-12 00:00:00
# 1    2014-09-23 00:00:00
# 2    2019-01-15 00:00:00
# 3    2018-07-30 00:00:00
# 4    2012-11-02 00:00:00
# 5    2020-06-18 00:00:00
# 6             2025-10-02
# 7    2025-10-02 00:00:00
# Name: JoinDate, dtype: object

# %%
df.dtypes
# Out:
# EmpID                  int64
# Name                  object
# Department            object
# Age                    int64
# Salary                 int64
# JoinDate      datetime64[ns]
# dtype: object

# %%
df["JoinDate"]=pd.to_datetime(df["JoinDate"])

# %%
df
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate
# 0    101   Rahul   Production   35   55000 2016-04-12
# 1    102    Amit  Maintenance   42   62000 2014-09-23
# 2    103   Sneha      Quality   29   48000 2019-01-15
# 3    104   Pooja   Production   31   51000 2018-07-30
# 4    105  Vikram    Logistics   45   68000 2012-11-02
# 5    106    Neha      Quality   27   45000 2020-06-18
# 6    107  Manish    Logistics   45   78000 2025-10-02
# 7    107  Manish    Logistics   45   78000 2025-10-02

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# dtype: bool

# %%
df.loc[6, "JoinDate"]
# Out:
# Timestamp('2025-10-02 00:00:00')

# %%
df.loc[6][5]
# Out:
# /tmp/ipykernel_2207/2144239396.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[6][5]
# Timestamp('2025-10-02 00:00:00')

# %%
df.iloc[6][5]
# Out:
# /tmp/ipykernel_2207/2995865776.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[6][5]
# Timestamp('2025-10-02 00:00:00')

# %%
df.sort_values("Salary",ascending=False)
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate
# 6    107  Manish    Logistics   45   78000 2025-10-02
# 7    107  Manish    Logistics   45   78000 2025-10-02
# 4    105  Vikram    Logistics   45   68000 2012-11-02
# 1    102    Amit  Maintenance   42   62000 2014-09-23
# 0    101   Rahul   Production   35   55000 2016-04-12
# 3    104   Pooja   Production   31   51000 2018-07-30
# 2    103   Sneha      Quality   29   48000 2019-01-15
# 5    106    Neha      Quality   27   45000 2020-06-18

# %%
df.sort_values("Salary",ascending=False).groupby("Department").head()
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate
# 6    107  Manish    Logistics   45   78000 2025-10-02
# 7    107  Manish    Logistics   45   78000 2025-10-02
# 4    105  Vikram    Logistics   45   68000 2012-11-02
# 1    102    Amit  Maintenance   42   62000 2014-09-23
# 0    101   Rahul   Production   35   55000 2016-04-12
# 3    104   Pooja   Production   31   51000 2018-07-30
# 2    103   Sneha      Quality   29   48000 2019-01-15
# 5    106    Neha      Quality   27   45000 2020-06-18

# %%
df["SalaryRank"]=df.groupby("Department")["Salary"].rank(method="dense",ascending=False)

# %%
df[["Salary","SalaryRank"]]
# Out:
#    Salary  SalaryRank
# 0   55000         1.0
# 1   62000         1.0
# 2   48000         1.0
# 3   51000         2.0
# 4   68000         2.0
# 5   45000         2.0
# 6   78000         1.0
# 7   78000         1.0

# %%
df.sort_values(by=["Department","SalaryRank"])
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate  SalaryRank
# 6    107  Manish    Logistics   45   78000 2025-10-02         1.0
# 7    107  Manish    Logistics   45   78000 2025-10-02         1.0
# 4    105  Vikram    Logistics   45   68000 2012-11-02         2.0
# 1    102    Amit  Maintenance   42   62000 2014-09-23         1.0
# 0    101   Rahul   Production   35   55000 2016-04-12         1.0
# 3    104   Pooja   Production   31   51000 2018-07-30         2.0
# 2    103   Sneha      Quality   29   48000 2019-01-15         1.0
# 5    106    Neha      Quality   27   45000 2020-06-18         2.0

# %%
df
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate  SalaryRank
# 0    101   Rahul   Production   35   55000 2016-04-12         1.0
# 1    102    Amit  Maintenance   42   62000 2014-09-23         1.0
# 2    103   Sneha      Quality   29   48000 2019-01-15         1.0
# 3    104   Pooja   Production   31   51000 2018-07-30         2.0
# 4    105  Vikram    Logistics   45   68000 2012-11-02         2.0
# 5    106    Neha      Quality   27   45000 2020-06-18         2.0
# 6    107  Manish    Logistics   45   78000 2025-10-02         1.0
# 7    107  Manish    Logistics   45   78000 2025-10-02         1.0

# %%
df.sort_values(["Department","Age"])
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate  SalaryRank
# 4    105  Vikram    Logistics   45   68000 2012-11-02         2.0
# 6    107  Manish    Logistics   45   78000 2025-10-02         1.0
# 7    107  Manish    Logistics   45   78000 2025-10-02         1.0
# 1    102    Amit  Maintenance   42   62000 2014-09-23         1.0
# 3    104   Pooja   Production   31   51000 2018-07-30         2.0
# 0    101   Rahul   Production   35   55000 2016-04-12         1.0
# 5    106    Neha      Quality   27   45000 2020-06-18         2.0
# 2    103   Sneha      Quality   29   48000 2019-01-15         1.0

# %%
df.sort_values(by=["Department","Age"],ascending=[False,True])
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate  SalaryRank
# 5    106    Neha      Quality   27   45000 2020-06-18         2.0
# 2    103   Sneha      Quality   29   48000 2019-01-15         1.0
# 3    104   Pooja   Production   31   51000 2018-07-30         2.0
# 0    101   Rahul   Production   35   55000 2016-04-12         1.0
# 1    102    Amit  Maintenance   42   62000 2014-09-23         1.0
# 4    105  Vikram    Logistics   45   68000 2012-11-02         2.0
# 6    107  Manish    Logistics   45   78000 2025-10-02         1.0
# 7    107  Manish    Logistics   45   78000 2025-10-02         1.0

# %%
df["JoiningRank"] =df["JoinDate"].rank()

# %%
df
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate  SalaryRank  JoiningRank
# 0    101   Rahul   Production   35   55000 2016-04-12         1.0          3.0
# 1    102    Amit  Maintenance   42   62000 2014-09-23         1.0          2.0
# 2    103   Sneha      Quality   29   48000 2019-01-15         1.0          5.0
# 3    104   Pooja   Production   31   51000 2018-07-30         2.0          4.0
# 4    105  Vikram    Logistics   45   68000 2012-11-02         2.0          1.0
# 5    106    Neha      Quality   27   45000 2020-06-18         2.0          6.0
# 6    107  Manish    Logistics   45   78000 2025-10-02         1.0          7.5
# 7    107  Manish    Logistics   45   78000 2025-10-02         1.0          7.5

# %%
df["JoiningRank1"]=df["JoinDate"].rank(method="dense")
df
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate  SalaryRank  \
# 0    101   Rahul   Production   35   55000 2016-04-12         1.0
# 1    102    Amit  Maintenance   42   62000 2014-09-23         1.0
# 2    103   Sneha      Quality   29   48000 2019-01-15         1.0
# 3    104   Pooja   Production   31   51000 2018-07-30         2.0
# 4    105  Vikram    Logistics   45   68000 2012-11-02         2.0
# 5    106    Neha      Quality   27   45000 2020-06-18         2.0
# 6    107  Manish    Logistics   45   78000 2025-10-02         1.0
# 7    107  Manish    Logistics   45   78000 2025-10-02         1.0
#
#    JoiningRank  JoiningRank1
# 0          3.0           3.0
# 1          2.0           2.0
# 2          5.0           5.0
# 3          4.0           4.0
# 4          1.0           1.0
# 5          6.0           6.0
# 6          7.5           7.0
# 7          7.5           7.0

# %%
df["JoiningRank1"]=df["JoinDate"].rank(method="min")
df
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate  SalaryRank  \
# 0    101   Rahul   Production   35   55000 2016-04-12         1.0
# 1    102    Amit  Maintenance   42   62000 2014-09-23         1.0
# 2    103   Sneha      Quality   29   48000 2019-01-15         1.0
# 3    104   Pooja   Production   31   51000 2018-07-30         2.0
# 4    105  Vikram    Logistics   45   68000 2012-11-02         2.0
# 5    106    Neha      Quality   27   45000 2020-06-18         2.0
# 6    107  Manish    Logistics   45   78000 2025-10-02         1.0
# 7    107  Manish    Logistics   45   78000 2025-10-02         1.0
#
#    JoiningRank  JoiningRank1
# 0          3.0           3.0
# 1          2.0           2.0
# 2          5.0           5.0
# 3          4.0           4.0
# 4          1.0           1.0
# 5          6.0           6.0
# 6          7.5           7.0
# 7          7.5           7.0

# %%
df["JoiningRank1"]=df["JoinDate"].rank(method="max")
df
# Out:
#    EmpID    Name   Department  Age  Salary   JoinDate  SalaryRank  \
# 0    101   Rahul   Production   35   55000 2016-04-12         1.0
# 1    102    Amit  Maintenance   42   62000 2014-09-23         1.0
# 2    103   Sneha      Quality   29   48000 2019-01-15         1.0
# 3    104   Pooja   Production   31   51000 2018-07-30         2.0
# 4    105  Vikram    Logistics   45   68000 2012-11-02         2.0
# 5    106    Neha      Quality   27   45000 2020-06-18         2.0
# 6    107  Manish    Logistics   45   78000 2025-10-02         1.0
# 7    107  Manish    Logistics   45   78000 2025-10-02         1.0
#
#    JoiningRank  JoiningRank1
# 0          3.0           3.0
# 1          2.0           2.0
# 2          5.0           5.0
# 3          4.0           4.0
# 4          1.0           1.0
# 5          6.0           6.0
# 6          7.5           8.0
# 7          7.5           8.0
